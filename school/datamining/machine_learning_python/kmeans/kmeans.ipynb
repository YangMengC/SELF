# %%
import sys
import os
searchPath=os.path.abspath('..')
sys.path.append(searchPath)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-be4593551213> in <module>
#       2 import sys
#       3 import os
# ----> 4 searchPath=os.path.abspath('..')
#       5 sys.path.append(searchPath)
#
# <ipython-input-12-be4593551213> in <module>
#       2 import sys
#       3 import os
# ----> 4 searchPath=os.path.abspath('..')
#       5 sys.path.append(searchPath)
#
# c:\Users\mengc\.vscode\extensions\ms-python.python-2021.6.944021595\pythonFiles\lib\python\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py in trace_dispatch(self, frame, event, arg)
#    1100                     if is_line:
#    1101                         self.set_suspend(thread, step_cmd, original_step_cmd=info.pydev_original_step_cmd)
# -> 1102                         self.do_wait_suspend(thread, frame, event, arg)
#    1103                     elif is_return:  # return event
#    1104                         back = frame.f_back
#
# c:\Users\mengc\.vscode\extensions\ms-python.python-2021.6.944021595\pythonFiles\lib\python\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py in do_wait_suspend(self, *args, **kwargs)
#     162
#     163     def do_wait_suspend(self, *args, **kwargs):
# --> 164         self._args[0].do_wait_suspend(*args, **kwargs)
#     165
#     166     # IFDEF CYTHON
#
# c:\Users\mengc\.vscode\extensions\ms-python.python-2021.6.944021595\pythonFiles\lib\python\debugpy\_vendored\pydevd\pydevd.py in do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    1935
#    1936             with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1937                 keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1938
#    1939         frames_list = None
#
# c:\Users\mengc\.vscode\extensions\ms-python.python-2021.6.944021595\pythonFiles\lib\python\debugpy\_vendored\pydevd\pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1970
#    1971             self.process_internal_commands()
# -> 1972             time.sleep(0.01)
#    1973
#    1974         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
from kmeans_base import KMeansBase
from kmeans_plus import KMeansPlusPlus
import time

from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn import datasets

import numpy as np

from misc_utils import distance, sortLabel
from kmeans_base import KMeansBase

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
allData = {"iris":datasets.load_iris().data, "boston":datasets.load_boston().data, "digits":datasets.load_digits().data}
models = {"KmeansBase":KMeansBase, "kmeans++":KMeansPlusPlus, "sklearnKmeans":KMeans}

# %%
for dataName, value in allData.items():
    n_clusters = 3
    init = "k-means++"
    if dataName == "digits":
        n_clusters = 10
    #降维
    tsne = TSNE(n_components=2, init='pca', random_state=0)
    X_tsne = tsne.fit_transform(value)
    for modelName, model in models.items():
        startTime = time.time()
        init = "k-means++"
        if modelName == "KmeansBase":
            init = "random"
        labels = model(n_clusters = n_clusters, init = init).fit_predict(value)
        takeTime = time.time() - startTime
        print("dataset=%s model=%s takeTime=%s"%(dataName, modelName, round(takeTime, 5)))
        plt.scatter(X_tsne[:, 0],X_tsne[:, 1], c=labels)
        plt.show()
    print("-" * 100)
# Out:
# dataset=iris model=KmeansBase takeTime=0.35014
# dataset=iris model=kmeans++ takeTime=0.26036
# dataset=iris model=sklearnKmeans takeTime=0.02596
# ----------------------------------------------------------------------------------------------------
# dataset=boston model=KmeansBase takeTime=1.01854
# dataset=boston model=kmeans++ takeTime=0.7733
# dataset=boston model=sklearnKmeans takeTime=0.02993
# ----------------------------------------------------------------------------------------------------
# dataset=digits model=KmeansBase takeTime=27.89248
# dataset=digits model=kmeans++ takeTime=25.43705
# dataset=digits model=sklearnKmeans takeTime=0.2863
# ----------------------------------------------------------------------------------------------------
